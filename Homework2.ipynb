# %% [markdown]
# <a href="https://colab.research.google.com/github/nutanicolaevna/homework/blob/HW2/Homework2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. x: = (10,10,10)
#   x1: = (0, 0, -10)
#   x: + x1: = (10, 10, 0)
# 2. Прямые кажутся не перпендикулярными, возможно из за разного масштаба сетки.
# 3. Ax + By + Cz +D = 0. Уравнение паралельной плоскости и проходящей через начала координат: А(x-xo) + B(y-yo) + C(z-zo) = 0
#
# Как узнать, принадлежит прямая плоскости или нет?
#
# Имея уравнение прямой мы знаем координаты 2-х точек A(x, y, z) & A1(x1,y1,z1), принадлежащих этой прямой, возьмем координаты этих точек и подставим в уравнение плоскости. Если при решении уравнения не выполняется равенство значит прямая не принадлежит этой плоскости.

# %%
import numpy as np

# %%
# Задание к уроку 2
# 2)
x = int(input('Введите координат х:'))
y = int(input('Введите координат y:'))

lenght_vect = np.sqrt(x**2 + y**2)
print(f'Длина вектора =', lenght_vect)
# Out:
# Введите координат х:5
# Введите координат y:6
# Длина вектора = 7.810249675906654

# %%
# Задание к уроку 2
# 4 1 График окружности

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt


x = []
y = []
x1 = []
y1 = []
for i in range(1500):
  r = 1000
  x.append(i)
  x1.append(-i)
  y.append(np.sqrt(r**2 - i**2))
  y1.append(-np.sqrt(r**2 - i**2))
plt.plot(x,y)
plt.plot(x,y1)
plt.plot(x1,y)
plt.plot(x1,y1)
plt.axis('scaled')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in sqrt
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in sqrt

# %%
x = []
y = []
x1 = []
y1 = []

for i in range(1500):
  a = 100
  b = 50
  x.append(i)
  x1.append(-i)
  y.append(np.sqrt(b**2 - (b**2*(i**2/a**2))))
  y1.append(-np.sqrt(b**2 -(b**2*(i**2/a**2))))
plt.plot(x,y)
plt.plot(x,y1)
plt.plot(x1,y)
plt.plot(x1,y1)
plt.axis('scaled')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in sqrt
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in sqrt
#   if sys.path[0] == '':

# %%
x = []
y = []
x1 = []
y1 = []

for i in range(1500):
  a = 400
  b = 300
  x.append(i)
  x1.append(-i)
  y.append(np.sqrt(b**2 + (b**2*(i**2/a**2))))
  y1.append(-np.sqrt(b**2 +(b**2*(i**2/a**2))))
plt.plot(x,y)
plt.plot(x,y1)
plt.plot(x1,y)
plt.plot(x1,y1)
plt.axis('scaled')
plt.show()

# %%
# 5
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = Axes3D(fig)
X = np.arange(-5, 5, 0.5)
Y = np.arange(-5, 5, 0.5)
X,Y = np.meshgrid(X,Y)
Z = 4*X + 6*Y
Z1 = 4*X + 6*Y + 500
ax.plot_surface(X,Y,Z)
ax.plot_wireframe(X,Y,Z1)
ax.scatter(0, 0, 0,'z',50,'red')
show()

# %%
fig = figure()
ax = Axes3D(fig)
X = np.arange(-5, 5, 0.5)
Y = np.arange(-5, 5, 0.5)
X,Y = np.meshgrid(X,Y)
Z = X**2 + Y**2


ax.plot_surface(X,Y,Z)


ax.scatter(0, 0, 0,'z',50,'red')
show()

# %%
fig = figure()
ax = Axes3D(fig)
a = 100
b = 5
X = np.arange(-5, 5, 0.5)
Y = np.arange(-5, 5, 0.5)
X,Y = np.meshgrid(X,Y)
Z = np.sqrt(X**2 + Y**2)



ax.plot_surface(X,Y,Z)



ax.scatter(0, 0, 0,'z',50,'red')
show()

# %% [markdown]
# Задание 33

# %% [markdown]
# 1.
# y(x) = k∙cos(x – a) + b

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2*np.pi, 3*np.pi, 201)


plt.plot(x, 3*np.cos(x-10) + 15)
plt.plot(x, 10*np.cos(x-3)+ 10)
plt.plot(x, 25*np.cos(x-5)+4)
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()

# %% [markdown]
# 2. Пусть точки M1(x1, y1) и M2(x2, y2) посредством ортогонального преобразования переводятся соответствено в точки M'1 (x'1, y'1) и M'2(x'2, y'2). Требуется доказать, что отрезки M1M2 и M'1M'2 имеют равные длины.
#
# Доказательство:
#
# |M'1M'2|^2 = [x'2-x'1]^2 + [y'2-y'1]^2 + [a11(x2-x1) + a12(y2-y1)]^2 + [a21(x2-x1) + a22(y2-y1)]^2 =
#
# = (a11^2 + a21^2) (x2-x1)^2 + (a12^2 + a22^2) (y2-y1)^2 + 2 (a11a12 + a21a22)(x2-x1)(y2-y1) =
#
# = (x2-x1)^2 + (y2-y1)^2 = |M1M2|^2
#
# Итак, |M1M2| = |M'1M'2|

# %% [markdown]
# 3.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math


def polar2cart(r,phi):
    x = r*math.cos(phi)
    y = r*math.sin(phi)
    return x,y

polar2cart(2,45)
# Out:
# (1.0506439776354595, 1.7018070490682369)

# %%
phi = np.arange(0., 2., 1./180.)*np.pi 

plt.polar(phi, [10]*len(phi)) 

plt.show()

# %%
phi = np.arange(4, 8, 2)
print(phi)
rho = np.arange(4, 8, 2)
print(rho)

plt.polar(phi, rho)         

plt.show()
# Out:
# [4 6]
# [4 6]

# %% [markdown]
# 4. exp(x) + x∙(1 – y) = 1
# y = x2 – 1

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(-2, 3, 201)

plt.figure(figsize = (6, 12))
plt.plot(x, (np.exp(x)+ x - 1)/x)
plt.plot(x, x**2 - 1)
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()

from scipy.optimize import fsolve

def my_system(p):
    x, y = p
    return (x**2 - 1 - y, np.exp(x) + x * (1 - y) - 1)

x, y =  fsolve(my_system, (4, 6))

              
print (x, y)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in true_divide
# 4.2001058411535706 16.640889076897693

# %% [markdown]
# y = x2 – 1
#
# exp(x) + x∙(1 – y)  - 1 > 0

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(-2, 5, 201)
plt.plot(x, x**2 -1)
plt.plot(x, (np.exp(x) - 1)/x)
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)

def f1(x):
    return x**2 - 1

def f2(x, y):
    return np.exp(x) + x * (1 - y) - 1

x1 = fsolve(f1, 2)
if f2(x1, f1(x1)) > 0:
  print(x,y)
# Out:
# [-2.000e+00 -1.965e+00 -1.930e+00 -1.895e+00 -1.860e+00 -1.825e+00
#  -1.790e+00 -1.755e+00 -1.720e+00 -1.685e+00 -1.650e+00 -1.615e+00
#  -1.580e+00 -1.545e+00 -1.510e+00 -1.475e+00 -1.440e+00 -1.405e+00
#  -1.370e+00 -1.335e+00 -1.300e+00 -1.265e+00 -1.230e+00 -1.195e+00
#  -1.160e+00 -1.125e+00 -1.090e+00 -1.055e+00 -1.020e+00 -9.850e-01
#  -9.500e-01 -9.150e-01 -8.800e-01 -8.450e-01 -8.100e-01 -7.750e-01
#  -7.400e-01 -7.050e-01 -6.700e-01 -6.350e-01 -6.000e-01 -5.650e-01
#  -5.300e-01 -4.950e-01 -4.600e-01 -4.250e-01 -3.900e-01 -3.550e-01
#  -3.200e-01 -2.850e-01 -2.500e-01 -2.150e-01 -1.800e-01 -1.450e-01
#  -1.100e-01 -7.500e-02 -4.000e-02 -5.000e-03  3.000e-02  6.500e-02
#   1.000e-01  1.350e-01  1.700e-01  2.050e-01  2.400e-01  2.750e-01
#   3.100e-01  3.450e-01  3.800e-01  4.150e-01  4.500e-01  4.850e-01
#   5.200e-01  5.550e-01  5.900e-01  6.250e-01  6.600e-01  6.950e-01
#   7.300e-01  7.650e-01  8.000e-01  8.350e-01  8.700e-01  9.050e-01
# ...
